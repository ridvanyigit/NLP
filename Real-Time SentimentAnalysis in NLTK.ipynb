# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Real-Time Sentiment Analysis of a Phone Call Using NLTK and TextBlob

# %%
#!pip install textblob
#!pip install nltk

# %%
import nltk
import textblob.download_corpora
from textblob import TextBlob as blob

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ridvanyigit/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/ridvanyigit/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/ridvanyigit/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/ridvanyigit/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tb = blob("Hi! 123 Tell me please, do you love me?")
print(tb)
# Out:
# Hi! 123 Tell me please, do you love me?

# %%
print(tb.tags)
# Out:
# [('Hi', 'NN'), ('123', 'CD'), ('Tell', 'NNP'), ('me', 'PRP'), ('please', 'NN'), ('do', 'VBP'), ('you', 'PRP'), ('love', 'VB'), ('me', 'PRP')]

# %%
tb.noun_phrases
# Out:
# WordList(['hi'])

# %%
tb.sentiment
# Out:
# Sentiment(polarity=0.5, subjectivity=0.6)

# %%
tb = blob('i love this page, it is very helpful')
tb.sentiment
# Out:
# Sentiment(polarity=0.35, subjectivity=0.44999999999999996)

# %% [markdown]
# ## Real-Time Voice Recording
# https://github.com/ridvanyigit/NLP/blob/main/Speech_Recognition.ipynb

# %%
#!pip install SpeechRecognition
#conda install pyaudio

# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
iter_num = 4
index = 0
while (index<iter_num):
    with sr.Microphone() as source:
        print("Speak Anything :")
        audio = r.listen(source, timeout=4)
        try:
            text = r.recognize_google(audio)
            tb = blob(text)
            print(text)
            print(tb.sentiment)
        except:
            print("Sorry could not recognize what you said")
        index = index + 1
# Out:
# Speak Anything :
# hey I was just thinking about you how is your day going
# Sentiment(polarity=0.0, subjectivity=0.0)
# Speak Anything :
# it's going well just a bit busy but hearing your voice
# Sentiment(polarity=0.1, subjectivity=0.3)
# Speak Anything :
# about you it was okay but it got a whole lot better now I was wondering if you had any plans for the weekend
# Sentiment(polarity=0.39999999999999997, subjectivity=0.4666666666666666)
# Speak Anything :
# I hate you don't call me again
# Sentiment(polarity=-0.8, subjectivity=0.9)
